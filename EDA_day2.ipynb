# %%
#import the libraries
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("C://Users//Astha//Downloads//train.csv") 
meal = pd.read_csv("C://Users//Astha//Downloads//meal.csv")
Humidity = pd.read_csv("C://Users//Astha//Downloads//Humidity.csv")
Weather = pd.read_csv("C://Users//Astha//Downloads//Weather.csv")

#importing csv file from desktop to python terminal
#we will replace the forward slashes by double backward slashes and at the end put the file name after double backward slash

# %%
train
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# 5       1270037     1         55     1248          251.23      252.23
# 6       1191377     1         55     1778          183.36      184.36
# 7       1499955     1         55     1062          182.36      183.36
# 8       1025244     1         55     2707          193.06      192.06
# 9       1054194     1         55     1207          325.92      384.18
# 10      1469367     1         55     1230          323.01      390.00
# 11      1029333     1         55     2322          322.07      388.00
# ...

# %%
Humidity.head()
# Out:
#        date      city  temperature  humidity
# 0  05/01/17  new york           65        56
# 1  05/02/17  new york           66        58
# 2  05/03/17  new york           68        60
# 3  05/01/17    mumbai           75        80
# 4  05/02/17    mumbai           78        83

# %%
Weather.head()
# Out:
#          day  chennai  chicago  berlin
# 0     Monday       75       32      41
# 1    Tuesday       77       30      43
# 2  Wednesday       75       28      45
# 3   Thursday       82       22      38
# 4     Friday       83       30      30

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456548 entries, 0 to 456547
# Data columns (total 9 columns):
# id                       456548 non-null int64
# week                     456548 non-null int64
# center_id                456548 non-null int64
# meal_id                  456548 non-null int64
# checkout_price           456548 non-null float64
# base_price               456548 non-null float64
# emailer_for_promotion    456548 non-null int64
# homepage_featured        456548 non-null int64
# num_orders               456548 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 31.3 MB

# %%
#check the first 5 rows of data - Data Preview
train.head() # by default head function gives first 5 rows of data
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                      0                  0         177
# 1                      0                  0         270
# 2                      0                  0         189
# 3                      0                  0          54
# 4                      0                  0          40

# %%
meal.head()
# Out:
#    meal_id   category cuisine
# 0     1885  Beverages    Thai
# 1     1993  Beverages    Thai
# 2     2539  Beverages    Thai
# 3     1248  Beverages  Indian
# 4     2631  Beverages  Indian

# %%
train.sort_values(by="num_orders" , ascending=False).head(10) # if we want to customize the number of rows , pass number of rows in the head parenthesis
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 14050   1452474     5         43     2290          159.08      311.43
# 19700   1300512     7         43     2290          159.08      311.43
# 16904   1087163     6         43     2290          156.20      310.43
# 13923   1470267     5         10     2290          162.99      309.43
# 413351  1346216   132         43     1971          204.70      324.04
# 12068   1352978     5         89     2290          162.02      309.43
# 90857   1238452    32        146     1754          194.03      268.69
# 12509   1091831     5        137     2290          159.11      307.49
# 12300   1002009     5         99     2290          162.02      309.49
# 85371   1398441    30        126     1754          144.56      279.36
#
#         emailer_for_promotion  homepage_featured  num_orders
# 14050                       1                  1       24299
# 19700                       1                  1       15336
# ...

# %%
#for bottom 5 rows
train.tail()
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders
# 456543                      0                  0          68
# 456544                      0                  0          42
# 456545                      0                  0         501
# 456546                      0                  0         729
# 456547                      0                  0         162

# %%
#shape of the data
train.shape
# Out:
# (456548, 9)

# %%
meal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
# meal_id     51 non-null int64
# category    51 non-null object
# cuisine     51 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# # Merge in Data Frames
#
# merging of data frames when we have two seperate data frames
# for merging we need to have atleast one column common

# %%
#Merge train and meals df and will pull the data of meals in the train data set
newtrain = pd.merge(train,meal)
#in the left hand side we put that table name where we want to merge the other table ie we want to add meal name to train table , both tables have meal_id as common

# %%
newtrain.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1040403     1         24     1885          136.83      136.83
# 2  1103215     1         11     1885          136.83      136.83
# 3  1034383     1         83     1885          121.31      120.31
# 4  1118999     1         32     1885          114.52      113.52
#
#    emailer_for_promotion  homepage_featured  num_orders   category cuisine
# 0                      0                  0         177  Beverages    Thai
# 1                      0                  0        1498  Beverages    Thai
# 2                      0                  0         959  Beverages    Thai
# 3                      0                  1        1025  Beverages    Thai
# 4                      0                  1         445  Beverages    Thai

# %%
newtrain.describe() #describe function only gives stats of numerical columns only
# Out:
#                  id           week      center_id        meal_id  \
# count  4.565480e+05  456548.000000  456548.000000  456548.000000
# mean   1.250096e+06      74.768771      82.105796    2024.337458
# std    1.443548e+05      41.524956      45.975046     547.420920
# min    1.000000e+06       1.000000      10.000000    1062.000000
# 25%    1.124999e+06      39.000000      43.000000    1558.000000
# 50%    1.250184e+06      76.000000      76.000000    1993.000000
# 75%    1.375140e+06     111.000000     110.000000    2539.000000
# max    1.499999e+06     145.000000     186.000000    2956.000000
#
#        checkout_price     base_price  emailer_for_promotion  \
# count   456548.000000  456548.000000          456548.000000
# mean       332.238933     354.156627               0.081152
# std        152.939723     160.715914               0.273069
# min          2.970000      55.350000               0.000000
# 25%        228.950000     243.500000               0.000000
# ...

# %%
#if we want to see the desc of string/categorical/object columns we use the same function
newtrain.describe(include="object")  #include will describe the data acc to string columns
#count number rows
#unique categories are 14 eg beverages etc
#top is mode - so the most repeated category is beverages
#freq is the number of times mode is repeated
# Out:
#          category  cuisine
# count      456548   456548
# unique         14        4
# top     Beverages  Italian
# freq       127890   122925

# %%
#Q1 what is the avg checkout price of pizzas ordered
#Q2 create a list of avg prices that too category wise

# %%
#way 1
newtrain.groupby("category").mean().loc["Pizza","checkout_price"]
# Out:
# 584.0041462973339

# %%
#way2
newtrain[newtrain.category=="Pizza"]["checkout_price"].mean()
# Out:
# 584.0041462973339

# %%
#way 3
pizza=newtrain[newtrain.category=="Pizza"]["checkout_price"]

# %%
pizza.mean()
# Out:
# 584.0041462973339

# %%
#Q2
newtrain.groupby("category").mean().loc[:,"checkout_price"]
# Out:
# category
# Beverages       213.264024
# Biryani         450.405156
# Desert          437.600166
# Extras          173.193299
# Fish            578.992080
# Other Snacks    258.132368
# Pasta           395.663210
# Pizza           584.004146
# Rice Bowl       317.532240
# Salad           290.955440
# Sandwich        289.988999
# Seafood         610.598550
# Soup            222.949614
# Starters        278.271997
# Name: checkout_price, dtype: float64

# %%
newtrain.groupby("category").mean().loc[:,"checkout_price"]
# Out:
# category
# Beverages       213.264024
# Biryani         450.405156
# Desert          437.600166
# Extras          173.193299
# Fish            578.992080
# Other Snacks    258.132368
# Pasta           395.663210
# Pizza           584.004146
# Rice Bowl       317.532240
# Salad           290.955440
# Sandwich        289.988999
# Seafood         610.598550
# Soup            222.949614
# Starters        278.271997
# Name: checkout_price, dtype: float64

# %%
#Q count the number of beverages 
newtrain[newtrain.category=="Beverages"].count()
# Out:
# id                       127890
# week                     127890
# center_id                127890
# meal_id                  127890
# checkout_price           127890
# base_price               127890
# emailer_for_promotion    127890
# homepage_featured        127890
# num_orders               127890
# category                 127890
# cuisine                  127890
# dtype: int64

# %%
newtrain.groupby("category").count().loc["Beverages","id"]

# %%
newtrain.category.value_counts()
# Out:
# Beverages       127890
# Rice Bowl        33408
# Sandwich         33291
# Pizza            33138
# Starters         29941
# Other Snacks     29379
# Desert           29294
# Salad            28559
# Pasta            27694
# Seafood          26916
# Biryani          20614
# Extras           13562
# Soup             12675
# Fish             10187
# Name: category, dtype: int64

# %%
#Q find out the median of beverages
newtrain[newtrain.category=="Beverages"]["checkout_price"].median()
# Out:
# 176.57

# %%
#Q
med_bev =newtrain[newtrain.category=="Beverages"]["checkout_price"].median()
round(med_bev,1)
# Out:
# 176.6

# %%
bev = newtrain[newtrain.category=="Beverages"]
bev
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1040403     1         24     1885          136.83      136.83
# 2       1103215     1         11     1885          136.83      136.83
# 3       1034383     1         83     1885          121.31      120.31
# 4       1118999     1         32     1885          114.52      113.52
# 5       1171094     1         13     1885          135.86      122.28
# 6       1472084     1        109     1885          134.86      134.86
# 7       1212128     1         52     1885          134.89      132.89
# 8       1297434     1         93     1885          116.46      116.46
# 9       1280872     1        186     1885          114.49      114.52
# 10      1140042     1        146     1885          115.46      113.49
# 11      1434245     1         57     1885          122.25      123.25
# ...

# %%
bev.category.count()
# Out:
# 127890

# %%
bev.category.value_counts()
# Out:
# Beverages    127890
# Name: category, dtype: int64

# %%
#value_Count
newtrain.category.count() #it will give us total count

# %%
newtrain.category.value_counts()

#value_counts is nothing but groupby of count function , value_counts() will give us counts categorywise

# %%
newtrain.groupby("category").count()["id"]
# Out:
# category
# Beverages       127890
# Biryani          20614
# Desert           29294
# Extras           13562
# Fish             10187
# Other Snacks     29379
# Pasta            27694
# Pizza            33138
# Rice Bowl        33408
# Salad            28559
# Sandwich         33291
# Seafood          26916
# Soup             12675
# Starters         29941
# Name: id, dtype: int64

# %%
newtrain[newtrain.category== "Seafood"]["category"].value_counts()
#newtrain[newtrain.category== "Seafood"]["id"].value_counts()
#newtrain[newtrain.category== "Seafood"]["cusuine"].value_counts() -- all will give same answer
# Out:
# Seafood    26916
# Name: category, dtype: int64

# %%
newtrain[newtrain.category== "Seafood"]["category"].count()
# Out:
# 26916

# %%
newtrain.category.value_counts()
# Out:
# Beverages       127890
# Rice Bowl        33408
# Sandwich         33291
# Pizza            33138
# Starters         29941
# Other Snacks     29379
# Desert           29294
# Salad            28559
# Pasta            27694
# Seafood          26916
# Biryani          20614
# Extras           13562
# Soup             12675
# Fish             10187
# Name: category, dtype: int64

# %%
#Unique - multiple entries -> Single entry
# unique will give the number of unique entries
newtrain.category.unique()
# Out:
# array(['Beverages', 'Rice Bowl', 'Starters', 'Pasta', 'Sandwich',
#        'Biryani', 'Extras', 'Pizza', 'Seafood', 'Other Snacks', 'Desert',
#        'Soup', 'Salad', 'Fish'], dtype=object)

# %%
#if you want to count number of unique elements
len(newtrain.category.unique()) #it will find the length of array "newtrain.category.unique()"
# Out:
# 14

# %%
#it will also give count of unique categories -- nunique function
newtrain.category.nunique()
# Out:
# 14

# %%
#Find the unique entries of cuisine
newtrain.cuisine.unique()
# Out:
# array(['Thai', 'Indian', 'Italian', 'Continental'], dtype=object)

# %%
##Find the number of cuisines

newtrain.cuisine.nunique()
# Out:
# 4

# %%
##Find the count cuisine values
newtrain.cuisine.value_counts()
# Out:
# Italian        122925
# Thai           118216
# Indian         112612
# Continental    102795
# Name: cuisine, dtype: int64

# %%
#where cuisine = thai find max checkout_price

newtrain[newtrain.cuisine=="Thai"]["checkout_price"].max()
# Out:
# 340.53

# %%
Weather
# Out:
#          day  chennai  chicago  berlin
# 0     Monday       75       32      41
# 1    Tuesday       77       30      43
# 2  Wednesday       75       28      45
# 3   Thursday       82       22      38
# 4     Friday       83       30      30
# 5   Saturday       81       20      45
# 6     Sunday       77       25      47

# %%
#reshaping data frame
#it will convert row values to columns acc to our convinient
pd.melt(Weather,id_vars="day") #id_vars is that column which we donot want to change

# %%
#rename the columns of melted data
new_weath=pd.melt(Weather,id_vars="day",var_name="City",value_name="Temp") #id_vars is that column which we donot want to change
#var_name=is the variable column name

# %%
new_weath
# Out:
#           day     City  Temp
# 0      Monday  chennai    75
# 1     Tuesday  chennai    77
# 2   Wednesday  chennai    75
# 3    Thursday  chennai    82
# 4      Friday  chennai    83
# 5    Saturday  chennai    81
# 6      Sunday  chennai    77
# 7      Monday  chicago    32
# 8     Tuesday  chicago    30
# 9   Wednesday  chicago    28
# 10   Thursday  chicago    22
# 11     Friday  chicago    30
# 12   Saturday  chicago    20
# 13     Sunday  chicago    25
# 14     Monday   berlin    41
# 15    Tuesday   berlin    43
# 16  Wednesday   berlin    45
# 17   Thursday   berlin    38
# 18     Friday   berlin    30
# 19   Saturday   berlin    45
# 20     Sunday   berlin    47

# %%
#find chennai data from reshaped table
new_weath[new_weath.City=="chennai"]
# Out:
#          day     City  Temp
# 0     Monday  chennai    75
# 1    Tuesday  chennai    77
# 2  Wednesday  chennai    75
# 3   Thursday  chennai    82
# 4     Friday  chennai    83
# 5   Saturday  chennai    81
# 6     Sunday  chennai    77

# %%
#reshape the weather df where city is berlin and give column name accordingly
pd.melt(Weather,id_vars="day",value_vars="berlin",var_name="City",value_name="Temp")
#value_vars is that value which we want to display, basically a check condition
# Out:
#          day    City  Temp
# 0     Monday  berlin    41
# 1    Tuesday  berlin    43
# 2  Wednesday  berlin    45
# 3   Thursday  berlin    38
# 4     Friday  berlin    30
# 5   Saturday  berlin    45
# 6     Sunday  berlin    47

# %%
train.info()

# %%
train.num_orders.mean()
# Out:
# 261.8727603669275

# %%
train.num_orders.std()
# Out:
# 395.92279774266024

# %%
train.num_orders.median()
# Out:
# 136.0

# %%
train.num_orders.var()
# Out:
# 156754.86177237544

# %%
Humidity.head()
# Out:
#        date      city  temperature  humidity
# 0  05/01/17  new york           65        56
# 1  05/02/17  new york           66        58
# 2  05/03/17  new york           68        60
# 3  05/01/17    mumbai           75        80
# 4  05/02/17    mumbai           78        83

# %%
#Pivots -- generate summary report or reshaped data
Humidity.pivot(index="date", columns="city" )
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 05/01/17          80     75       65       26     80       56
# 05/02/17          77     78       66       30     83       58
# 05/03/17          79     82       68       35     85       60

# %%
Humidity.pivot(index="date", columns="city" ).min()
# Out:
#              city
# temperature  beijing     77
#              mumbai      75
#              new york    65
# humidity     beijing     26
#              mumbai      80
#              new york    56
# dtype: int64

# %%
Humidity.T  #T means transpose
# Out:
#                     0         1         2         3         4         5  \
# date         05/01/17  05/02/17  05/03/17  05/01/17  05/02/17  05/03/17
# city         new york  new york  new york    mumbai    mumbai    mumbai
# temperature        65        66        68        75        78        82
# humidity           56        58        60        80        83        85
#
#                     6         7         8
# date         05/01/17  05/02/17  05/03/17
# city          beijing   beijing   beijing
# temperature        80        77        79
# humidity           26        30        35

# %%
#avg of humidity n temp
Humidity.pivot_table(index="date") #the index defines the way you want the stats or values
# Out:
#           humidity  temperature
# date
# 05/01/17        54    73.333333
# 05/02/17        57    73.666667
# 05/03/17        60    76.333333

# %%
#Avg cusine wise
newtrain.pivot_table(values="checkout_price",columns="cuisine",aggfunc="mean").T

#here values is where we want to apply aggregate function, column is groupby which column ie cuisine here and by default aggregate function is mean in pivot table
# Out:
#              checkout_price
# cuisine
# Continental      515.978809
# Indian           340.769833
# Italian          285.133102
# Thai             213.323235
